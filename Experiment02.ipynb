# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
marks = pd.read_csv(r"C:\Users\ppawa\Pranav\Study\Engineering\SEM 4\DMA\LabWork\DMA-Codes\Student_Marks.csv")

# %%
marks.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
x=marks['Marks']
y=marks['time_study']
plt.plot(x)
plt.plot(y)

# %%
plt.plot(y,marker="*",linestyle="dotted")

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.show()

# %%
print(marks.head())
print(marks.tail())
print(marks["number_courses"])
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299
#     number_courses  time_study   Marks
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
# 0     3
# 1     4
# 2     4
# 3     6
# 4     8
#      ..
# 95    6
# 96    3
# 97    4
# 98    7
# 99    3
# Name: number_courses, Length: 100, dtype: int64

# %%
print(marks.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB
# None

# %%
marks.isnull().sum()
# Out:
# number_courses    0
# time_study        0
# Marks             0
# dtype: int64

# %%
numerical_columns = marks.select_dtypes(include=['int64', 'float64','float64']).columns
for column in numerical_columns:
    plt.figure(figsize=(8, 6))
    sns.histplot(marks[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
time=marks['time_study']
sns.histplot(time, kde=True)
plt.show()
